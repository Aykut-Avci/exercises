# %% [markdown]
# # HOLIDAY PREFERENCE

# %% [markdown]
# > In this notebook favourite holiday is described

# %%
from IPython.display import Image
Image("https://static.independent.co.uk/s3fs-public/thumbnails/image/2018/08/01/21/man-summer-holiday.jpg",width=200,height=200)

# %%
def name():
    
    #This function displays the name of the person 
    
    
    from IPython.display import Markdown as md
    A = input("Please enter a name")
    A = A.upper()
    return md("{}'S HOLIDAY PREFERENCE".format(A))

# %%
name()

# %%
from IPython.display import Image
Image("https://img.traveltriangle.com/blog/wp-content/uploads/2017/05/Cover11.jpg")

# %% [markdown]
# He likes to do these activities:
# * Sightseeing
# * Eating-Out
# * Shopping
